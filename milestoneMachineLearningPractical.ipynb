# %% [markdown]
# <a href="https://colab.research.google.com/github/quamrl-hoda/pwAssignment_/blob/main/milestoneMachineLearningPractical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Machine learning Practical question:

# %% [markdown]
# ### 1. Do the EDA on the given dataset: Lung cancer, and extract some useful information from this.

# %% [markdown]
# ###Dataset Description:
#
# - Lung cancer is one of the most prevalent and deadly forms of cancer worldwide, presenting significant challenges in early detection and effective treatment. To aid in the global effort to understand and combat this disease, we are excited to introduce our comprehensive Lung Cancer Dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/lungCancer.csv")

# %%
df
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
# Display the first few rows of the dataset
df.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# ...

# %%
# Check the shape of the dataset
df.shape
# Out:
# (309, 16)

# %%
df.tail()
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 304                2         2         1         1                  2
# 305                1         2         2         2                  2
# 306                1         1         2         2                  2
# 307                1         2         2         1                  2
# 308                1         2         2         2                  2
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 304         2                    2                      2           1
# ...

# %%
# Display the first any rows of the dataset
df.sample(1)
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 276      F   62        2               2        2              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 276                2         2         1         1                  1
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 276         2                    2                      1           1
#
#     LUNG_CANCER
# 276         YES

# %%
print(df.columns.values)
# Out:
# ['GENDER' 'AGE' 'SMOKING' 'YELLOW_FINGERS' 'ANXIETY' 'PEER_PRESSURE'
#  'CHRONIC DISEASE' 'FATIGUE ' 'ALLERGY ' 'WHEEZING' 'ALCOHOL CONSUMING'
#  'COUGHING' 'SHORTNESS OF BREATH' 'SWALLOWING DIFFICULTY' 'CHEST PAIN'
#  'LUNG_CANCER']

# %%
# Check data types and missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
# ...

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL CONSUMING        0
# COUGHING                 0
# SHORTNESS OF BREATH      0
# SWALLOWING DIFFICULTY    0
# CHEST PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
# Summary statistics for numerical columns
df.describe()
# Out:
#               AGE     SMOKING  YELLOW_FINGERS     ANXIETY  PEER_PRESSURE  \
# count  309.000000  309.000000      309.000000  309.000000     309.000000
# mean    62.673139    1.563107        1.569579    1.498382       1.501618
# std      8.210301    0.496806        0.495938    0.500808       0.500808
# min     21.000000    1.000000        1.000000    1.000000       1.000000
# 25%     57.000000    1.000000        1.000000    1.000000       1.000000
# 50%     62.000000    2.000000        2.000000    1.000000       2.000000
# 75%     69.000000    2.000000        2.000000    2.000000       2.000000
# max     87.000000    2.000000        2.000000    2.000000       2.000000
#
#        CHRONIC DISEASE    FATIGUE     ALLERGY     WHEEZING  ALCOHOL CONSUMING  \
# count       309.000000  309.000000  309.000000  309.000000         309.000000
# mean          1.504854    1.673139    1.556634    1.556634           1.556634
# ...

# %%
# Summary statistics for categorical columns
df.describe(include = ['object'])
# Out:
#        GENDER LUNG_CANCER
# count     309         309
# unique      2           2
# top         M         YES
# freq      162         270

# %%
df['LUNG_CANCER'].value_counts(normalize = True)*100
# Out:
# LUNG_CANCER
# YES    87.378641
# NO     12.621359
# Name: proportion, dtype: float64

# %%
#dropping all empty rows and columns
df.dropna(axis =1, how = 'all', inplace = True)
df.dropna(axis =0, how = 'all', inplace = True)

# %%
df.shape
# Out:
# (309, 16)

# %%
for column in df.columns:
    print(f"The missing value for {column} is {df[column].isnull().sum()}")
# Out:
# The missing value for GENDER is 0
# The missing value for AGE is 0
# The missing value for SMOKING is 0
# The missing value for YELLOW_FINGERS is 0
# The missing value for ANXIETY is 0
# The missing value for PEER_PRESSURE is 0
# The missing value for CHRONIC DISEASE is 0
# The missing value for FATIGUE  is 0
# The missing value for ALLERGY  is 0
# The missing value for WHEEZING is 0
# The missing value for ALCOHOL CONSUMING is 0
# The missing value for COUGHING is 0
# The missing value for SHORTNESS OF BREATH is 0
# The missing value for SWALLOWING DIFFICULTY is 0
# The missing value for CHEST PAIN is 0
# The missing value for LUNG_CANCER is 0

# %%
# Count plot for Lung Cancer cases
sns.countplot(data = df, x='LUNG_CANCER')
plt.title('Distribution of Lung Cancer Cases')
plt.show()

# %%
# Count plot for Smoking status vs Lung Cancer
sns.countplot(data = df, x='SMOKING', hue='LUNG_CANCER')
plt.title('Smoking Status vs Lung Cancer')
plt.show()

# %%
# Convert categorical variables to numerical for correlation analysis
data_encoded = df.copy()
data_encoded['GENDER'] = data_encoded['GENDER'].map({'M': 1, 'F': 0})
data_encoded['LUNG_CANCER'] = data_encoded['LUNG_CANCER'].map({'YES': 1, 'NO': 0})

# Calculate correlations
correlation_matrix = data_encoded.corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Histogram of Age
sns.histplot(df['AGE'], bins=20)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Boxplot for Age vs Lung Cancer
sns.boxplot(x='LUNG_CANCER', y='AGE', data=df)
plt.title('Age Distribution by Lung Cancer Status')
plt.show()

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
# Filter data for patients with lung cancer
lung_cancer_data = df[df['LUNG_CANCER'] == 'YES']

# Count occurrences of each symptom
symptom_columns = ['FATIGUE ', 'ALLERGY ', 'WHEEZING', 'COUGHING', 'SHORTNESS OF BREATH', 'SWALLOWING DIFFICULTY', 'CHEST PAIN']
symptom_counts = {symptom: lung_cancer_data[symptom].value_counts() for symptom in symptom_columns}

# Display counts for each symptom
for symptom, counts in symptom_counts.items():
    print(f"\nCounts for {symptom}:")
    print(counts)
# Out:
# Counts for FATIGUE :
# FATIGUE
# 2    189
# 1     81
# Name: count, dtype: int64
#
# Counts for ALLERGY :
# ALLERGY
# 2    167
# 1    103
# Name: count, dtype: int64
#
# Counts for WHEEZING:
# WHEEZING
# 2    163
# 1    107
# Name: count, dtype: int64
#
# Counts for COUGHING:
# COUGHING
# 2    169
# 1    101
# Name: count, dtype: int64
#
# Counts for SHORTNESS OF BREATH:
# SHORTNESS OF BREATH
# 2    176
# 1     94
# Name: count, dtype: int64
#
# Counts for SWALLOWING DIFFICULTY:
# SWALLOWING DIFFICULTY
# 2    140
# 1    130
# Name: count, dtype: int64
#
# Counts for CHEST PAIN:
# CHEST PAIN
# 2    160
# 1    110
# Name: count, dtype: int64

# %%
# Set up a figure for plotting
plt.figure(figsize=(14, 8))

# Plot each symptom's counts
for i, symptom in enumerate(symptom_columns):
    plt.subplot(3, 3, i + 1)
    sns.countplot(data=lung_cancer_data, x=symptom, order=lung_cancer_data[symptom].value_counts().index)
    plt.title(f'Distribution of {symptom}')
    plt.xlabel(symptom)
    plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %%
# Display unique values for 'CHEST PAIN' and 'LUNG_CANCER'
print("Unique values in CHEST PAIN:", df['CHEST PAIN'].unique())
print("Unique values in LUNG CANCER:", df['LUNG_CANCER'].unique())
# Out:
# Unique values in CHEST PAIN: [2 1]
# Unique values in LUNG CANCER: ['YES' 'NO']

# %%
# Create a contingency table
contingency_table = pd.crosstab(df['CHEST PAIN'], df['LUNG_CANCER'])
print("Contingency Table:")
print(contingency_table)

# Calculate percentages
contingency_percentage = contingency_table.div(contingency_table.sum(axis=1), axis=0) * 100
print("\nPercentage Table:")
print(contingency_percentage)
# Out:
# Contingency Table:
# LUNG_CANCER  NO  YES
# CHEST PAIN
# 1            27  110
# 2            12  160
#
# Percentage Table:
# LUNG_CANCER         NO        YES
# CHEST PAIN
# 1            19.708029  80.291971
# 2             6.976744  93.023256

# %%
# Plotting the correlation between chest pain and lung cancer diagnosis
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='CHEST PAIN', hue='LUNG_CANCER')
plt.title('Correlation between Chest Pain and Lung Cancer Diagnosis')
plt.xlabel('Chest Pain')
plt.ylabel('Count')
plt.legend(title='Lung Cancer', loc='upper right', labels=['No', 'Yes'])
plt.show()

# %%
# Display unique values for relevant symptom columns
symptom_columns = ['FATIGUE ', 'ALLERGY ', 'WHEEZING', 'COUGHING', 'SHORTNESS OF BREATH', 'SWALLOWING DIFFICULTY', 'CHEST PAIN']
for symptom in symptom_columns:
    print(f"Unique values in {symptom}:", df[symptom].unique())
# Out:
# Unique values in FATIGUE : [2 1]
# Unique values in ALLERGY : [1 2]
# Unique values in WHEEZING: [2 1]
# Unique values in COUGHING: [2 1]
# Unique values in SHORTNESS OF BREATH: [2 1]
# Unique values in SWALLOWING DIFFICULTY: [2 1]
# Unique values in CHEST PAIN: [2 1]

# %%
# Create a function to generate contingency tables for symptoms vs lung cancer
def create_contingency_table(symptom):
    return pd.crosstab(df[symptom], df['LUNG_CANCER'], margins=True)

# Analyze each symptom in relation to lung cancer
contingency_tables = {}
for symptom in symptom_columns:
    contingency_tables[symptom] = create_contingency_table(symptom)
    print(f"\nContingency Table for {symptom}:")
    print(contingency_tables[symptom])
# Out:
# Contingency Table for FATIGUE :
# LUNG_CANCER  NO  YES  All
# FATIGUE
# 1            20   81  101
# 2            19  189  208
# All          39  270  309
#
# Contingency Table for ALLERGY :
# LUNG_CANCER  NO  YES  All
# ALLERGY
# 1            34  103  137
# 2             5  167  172
# All          39  270  309
#
# Contingency Table for WHEEZING:
# LUNG_CANCER  NO  YES  All
# WHEEZING
# 1            30  107  137
# 2             9  163  172
# All          39  270  309
#
# Contingency Table for COUGHING:
# LUNG_CANCER  NO  YES  All
# COUGHING
# 1            29  101  130
# 2            10  169  179
# All          39  270  309
#
# Contingency Table for SHORTNESS OF BREATH:
# LUNG_CANCER          NO  YES  All
# SHORTNESS OF BREATH
# 1                    17   94  111
# 2                    22  176  198
# All                  39  270  309
#
# Contingency Table for SWALLOWING DIFFICULTY:
# LUNG_CANCER            NO  YES  All
# SWALLOWING DIFFICULTY
# 1                      34  130  164
# ...

# %%
# Calculate percentages for each symptom's contingency table
percentage_tables = {}
for symptom, table in contingency_tables.items():
    percentage_tables[symptom] = table.div(table.sum(axis=1), axis=0) * 100
    print(f"\nPercentage Table for {symptom}:")
    print(percentage_tables[symptom])
# Out:
# Percentage Table for FATIGUE :
# LUNG_CANCER        NO        YES   All
# FATIGUE
# 1            9.900990  40.099010  50.0
# 2            4.567308  45.432692  50.0
# All          6.310680  43.689320  50.0
#
# Percentage Table for ALLERGY :
# LUNG_CANCER         NO        YES   All
# ALLERGY
# 1            12.408759  37.591241  50.0
# 2             1.453488  48.546512  50.0
# All           6.310680  43.689320  50.0
#
# Percentage Table for WHEEZING:
# LUNG_CANCER         NO        YES   All
# WHEEZING
# 1            10.948905  39.051095  50.0
# 2             2.616279  47.383721  50.0
# All           6.310680  43.689320  50.0
#
# Percentage Table for COUGHING:
# LUNG_CANCER         NO        YES   All
# COUGHING
# 1            11.153846  38.846154  50.0
# 2             2.793296  47.206704  50.0
# All           6.310680  43.689320  50.0
#
# Percentage Table for SHORTNESS OF BREATH:
# LUNG_CANCER                NO        YES   All
# SHORTNESS OF BREATH
# ...

# %%
# Set up a figure for plotting
plt.figure(figsize=(14, 10))

# Plotting each symptom's correlation with lung cancer diagnosis
for i, symptom in enumerate(symptom_columns):
    plt.subplot(3, 3, i + 1)
    sns.countplot(data=df, x=symptom, hue='LUNG_CANCER')
    plt.title(f'Correlation between {symptom} and Lung Cancer Diagnosis')
    plt.xlabel(symptom)
    plt.ylabel('Count')
    plt.legend(title='Lung Cancer', loc='upper right', labels=['No', 'Yes'])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2. Do the Eda on this Dataset :Presidential Election Polls 2024 Dataset and extract useful information from this:

# %% [markdown]
# ###Dataset Description:
#
# - This dataset comprises the results of a nationwide presidential election poll conducted on March 4, 2024. The data offers various insights but does not align with the official election results. You are encouraged to create your notebooks and delve into the data for further exploration.

# %%
data = pd.read_csv("/content/election2024.csv")

# %%
data
# Out:
#                     id     sex   age federal_district  \
# 0     07169ed8148ce047    male  18.0  north caucasian
# 1     0716a4f3354cecdd    male  23.0  north caucasian
# 2     0716889b304ce79c    male  20.0            volga
# 3     07168e28b5cce563    male  22.0     northwestern
# 4     0716a563914ce549    male  21.0         southern
# ...                ...     ...   ...              ...
# 1595  0716b23c2c0cee3a    male  61.0          central
# 1596  07168254d14ceb55  female  80.0            volga
# 1597  071690f34d4ce164  female  76.0     northwestern
# 1598  0716bfa9c48ce79a  female  74.0          central
# 1599  07168088318cef88  female  76.0             ural
#
#                                       type_of_city    knows_election_date  \
# 0                                          village     named correct date
# 1                                          village     named correct date
# 2            city with population of less than 50k     named correct date
# ...

# %%
data.head()
# Out:
#                  id   sex   age federal_district  \
# 0  07169ed8148ce047  male  18.0  north caucasian
# 1  0716a4f3354cecdd  male  23.0  north caucasian
# 2  0716889b304ce79c  male  20.0            volga
# 3  07168e28b5cce563  male  22.0     northwestern
# 4  0716a563914ce549  male  21.0         southern
#
#                                    type_of_city    knows_election_date  \
# 0                                       village     named correct date
# 1                                       village     named correct date
# 2         city with population of less than 50k     named correct date
# 3  city with population of 1 million and higher  not sure or no answer
# 4  city with population of 1 million and higher     named correct date
#
#         will_vote candidate      television_usage      internet_usage  \
# 0        not sure     Putin  several times a week  over 4 hours a day
# 1        not sure     Putin      once half a year  over 4 hours a day
# ...

# %%
data.tail()
# Out:
#                     id     sex   age federal_district  \
# 1595  0716b23c2c0cee3a    male  61.0          central
# 1596  07168254d14ceb55  female  80.0            volga
# 1597  071690f34d4ce164  female  76.0     northwestern
# 1598  0716bfa9c48ce79a  female  74.0          central
# 1599  07168088318cef88  female  76.0             ural
#
#                                type_of_city    knows_election_date  \
# 1595                             settlement     named correct date
# 1596                                village     named correct date
# 1597        city with population of 50-100k     named correct date
# 1598  city with population of less than 50k  not sure or no answer
# 1599                                village     named correct date
#
#            will_vote           candidate      television_usage  \
# 1595   definitely no  will not take part    over 4 hours a day
# 1596      likely yes  struggle to answer  several times a week
# ...

# %%
data.sample(2)
# Out:
#                     id   sex   age federal_district  \
# 1111  07166a27070ce455  male  70.0         siberian
# 299   0716a4b33a8ce510  male  57.0  north caucasian
#
#                           type_of_city knows_election_date       will_vote  \
# 1111                           village  named correct date  definitely yes
# 299   city with population of 100-500k  named correct date  definitely yes
#
#      candidate         television_usage           internet_usage  \
# 1111  Slutskiy  less than 4 hours a day  less than 4 hours a day
# 299      Putin  less than 4 hours a day  less than 4 hours a day
#
#                         education  income            employment  \
# 1111  incomplete school education  medium  unemployed pensioner
# 299                       college    high         work for hire
#
#                job_type             company_type   weight1
# 1111                NaN                      NaN  1.057197
# 299   government agency  industry, manufacturing  0.644393

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1600 non-null   object
#  1   sex                  1600 non-null   object
#  2   age                  1600 non-null   float64
#  3   federal_district     1600 non-null   object
#  4   type_of_city         1600 non-null   object
#  5   knows_election_date  1600 non-null   object
#  6   will_vote            1600 non-null   object
#  7   candidate            1600 non-null   object
#  8   television_usage     1600 non-null   object
#  9   internet_usage       1600 non-null   object
#  10  education            1600 non-null   object
#  11  income               1600 non-null   object
#  12  employment           1600 non-null   object
#  13  job_type             692 non-null    object
#  14  company_type         879 non-null    object
# ...

# %%
data.isnull().sum()
# Out:
# id                       0
# sex                      0
# age                      0
# federal_district         0
# type_of_city             0
# knows_election_date      0
# will_vote                0
# candidate                0
# television_usage         0
# internet_usage           0
# education                0
# income                   0
# employment               0
# job_type               908
# company_type           721
# weight1                  0
# dtype: int64

# %%
#dropping all empty rows and columns
data.dropna(axis =1, how = 'all', inplace = True)
data.dropna(axis =0, how = 'all', inplace = True)

# %%
data = data.drop('id', axis=1)

# %%
data.head()
# Out:
#     sex   age federal_district                                  type_of_city  \
# 0  male  18.0  north caucasian                                       village
# 1  male  23.0  north caucasian                                       village
# 2  male  20.0            volga         city with population of less than 50k
# 3  male  22.0     northwestern  city with population of 1 million and higher
# 4  male  21.0         southern  city with population of 1 million and higher
#
#      knows_election_date       will_vote candidate      television_usage  \
# 0     named correct date        not sure     Putin  several times a week
# 1     named correct date        not sure     Putin      once half a year
# 2     named correct date  definitely yes     Putin  several times a week
# 3  not sure or no answer        not sure  Davankov  several times a week
# 4     named correct date  definitely yes     Putin        does not watch
#
# ...

# %%
data
# Out:
#          sex   age federal_district  \
# 0       male  18.0  north caucasian
# 1       male  23.0  north caucasian
# 2       male  20.0            volga
# 3       male  22.0     northwestern
# 4       male  21.0         southern
# ...      ...   ...              ...
# 1595    male  61.0          central
# 1596  female  80.0            volga
# 1597  female  76.0     northwestern
# 1598  female  74.0          central
# 1599  female  76.0             ural
#
#                                       type_of_city    knows_election_date  \
# 0                                          village     named correct date
# 1                                          village     named correct date
# 2            city with population of less than 50k     named correct date
# 3     city with population of 1 million and higher  not sure or no answer
# 4     city with population of 1 million and higher     named correct date
# ...                                            ...                    ...
# ...

# %%
df.isnull().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL CONSUMING        0
# COUGHING                 0
# SHORTNESS OF BREATH      0
# SWALLOWING DIFFICULTY    0
# CHEST PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
data.describe()
# Out:
#                age      weight1
# count  1600.000000  1600.000000
# mean     49.936250     1.000000
# std      16.901797     0.327084
# min      18.000000     0.468226
# 25%      37.000000     0.772224
# 50%      49.000000     0.921724
# 75%      64.000000     1.158913
# max      90.000000     2.515072

# %%
data.describe(include=['object'])
# Out:
#            sex federal_district                      type_of_city  \
# count     1600             1600                              1600
# unique       2                8                                 7
# top     female          central  city with population of 100-500k
# freq       843              425                               391
#
#        knows_election_date       will_vote candidate         television_usage  \
# count                 1600            1600      1600                     1600
# unique                   4               6         7                        6
# top     named correct date  definitely yes     Putin  less than 4 hours a day
# freq                  1361            1062      1128                      490
#
#                  internet_usage education  income     employment  \
# count                      1600      1600    1600           1600
# unique                        6         6       6             11
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   sex                  1600 non-null   object
#  1   age                  1600 non-null   float64
#  2   federal_district     1600 non-null   object
#  3   type_of_city         1600 non-null   object
#  4   knows_election_date  1600 non-null   object
#  5   will_vote            1600 non-null   object
#  6   candidate            1600 non-null   object
#  7   television_usage     1600 non-null   object
#  8   internet_usage       1600 non-null   object
#  9   education            1600 non-null   object
#  10  income               1600 non-null   object
#  11  employment           1600 non-null   object
#  12  job_type             692 non-null    object
#  13  company_type         879 non-null    object
#  14  weight1              1600 non-null   float64
# ...

# %%
data.columns
# Out:
# Index(['sex', 'age', 'federal_district', 'type_of_city', 'knows_election_date',
#        'will_vote', 'candidate', 'television_usage', 'internet_usage',
#        'education', 'income', 'employment', 'job_type', 'company_type',
#        'weight1'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# Convert categorical columns to numerical using Label Encoding
label_columns = ['sex','federal_district','type_of_city', 'knows_election_date', 'will_vote', 'candidate', 'television_usage', 'internet_usage', 'education', 'income', 'employment', 'job_type', 'company_type']
label_encoder = LabelEncoder()

# Use 'data' instead of 'df' to apply Label Encoding to the correct DataFrame
for column in label_columns:
    data[column] = label_encoder.fit_transform(data[column])  # Changed 'df' to 'data'

# Convert age column from string to float
data['age'] = data['age'].astype(float)  # Changed 'df' to 'data'

# Display the updated DataFrame
print("\nDataFrame after conversion:")
print(data.head())  # Changed 'df' to 'data'
# Out:
# DataFrame after conversion:
#    sex   age  federal_district  type_of_city  knows_election_date  will_vote  \
# 0    1  18.0                 2             6                    0          4
# 1    1  23.0                 2             6                    0          4
# 2    1  20.0                 7             4                    0          1
# 3    1  22.0                 3             0                    2          4
# 4    1  21.0                 5             0                    0          1
#
#    candidate  television_usage  internet_usage  education  income  employment  \
# 0          2                 5               3          3       4           2
# 1          2                 2               3          2       4          10
# 2          2                 5               3          2       4          10
# 3          0                 5               3          2       4           7
# 4          2                 0               3          1       4           1
#
# ...

# %%
data
# Out:
#       sex   age  federal_district  type_of_city  knows_election_date  \
# 0       1  18.0                 2             6                    0
# 1       1  23.0                 2             6                    0
# 2       1  20.0                 7             4                    0
# 3       1  22.0                 3             0                    2
# 4       1  21.0                 5             0                    0
# ...   ...   ...               ...           ...                  ...
# 1595    1  61.0                 0             5                    0
# 1596    0  80.0                 7             6                    0
# 1597    0  76.0                 3             2                    0
# 1598    0  74.0                 0             4                    2
# 1599    0  76.0                 6             6                    0
#
#       will_vote  candidate  television_usage  internet_usage  education  \
# ...

# %% [markdown]
# ### Visualizations

# %%
# Count plot for voting intention
sns.countplot(data=data, x='will_vote', hue='candidate')
plt.title('Voting Intention by Candidate')
plt.xlabel('Will Vote')
plt.ylabel('Count')
plt.legend(title='Candidate')
plt.show()

# %%
# Histogram of Age
sns.histplot(data['age'], bins=20)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   sex                  1600 non-null   int64
#  1   age                  1600 non-null   float64
#  2   federal_district     1600 non-null   int64
#  3   type_of_city         1600 non-null   int64
#  4   knows_election_date  1600 non-null   int64
#  5   will_vote            1600 non-null   int64
#  6   candidate            1600 non-null   int64
#  7   television_usage     1600 non-null   int64
#  8   internet_usage       1600 non-null   int64
#  9   education            1600 non-null   int64
#  10  income               1600 non-null   int64
#  11  employment           1600 non-null   int64
#  12  job_type             1600 non-null   int64
#  13  company_type         1600 non-null   int64
#  14  weight1              1600 non-null   float64
# dtypes: float64(2), int64(13)
# ...

# %%
data.sample(1)
# Out:
#      sex   age  federal_district  type_of_city  knows_election_date  \
# 459    1  18.0                 3             1                    1
#
#      will_vote  candidate  television_usage  internet_usage  education  \
# 459          2          0                 0               1          3
#
#      income  employment  job_type  company_type   weight1
# 459       3          10         0            18  0.856012

# %%
# Convert categorical variables to numerical for correlation analysis if needed
data_encoded = data.copy()
data_encoded['sex'] = data_encoded['sex'].map({'male': 1, 'female': 0})

# Calculate correlations (only for numerical columns)
correlation_matrix = data_encoded.corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ###  Demographic Analysis

# %% [markdown]
# ###Analyze Gender Distribution

# %%
# Count occurrences of each gender
gender_counts = data['sex'].value_counts()
print("\nGender Distribution:")
print(gender_counts)
# Out:
# Gender Distribution:
# sex
# 0    843
# 1    757
# Name: count, dtype: int64

# %%
#Analyze Age Distribution
# Summary statistics for age
age_summary = data['age'].describe()
print("\nAge Summary Statistics:")
print(age_summary)
# Out:
# Age Summary Statistics:
# count    1600.000000
# mean       49.936250
# std        16.901797
# min        18.000000
# 25%        37.000000
# 50%        49.000000
# 75%        64.000000
# max        90.000000
# Name: age, dtype: float64

# %%
#Analyze Education Level Distribution
# Count occurrences of each education level
education_counts = data['education'].value_counts()
print("\nEducation Level Distribution:")
print(education_counts)
# Out:
# Education Level Distribution:
# education
# 2    690
# 1    550
# 5    181
# 0     95
# 3     80
# 4      4
# Name: count, dtype: int64

# %%
#Analyze Income Distribution
# Count occurrences of each income level
income_counts = data['income'].value_counts()
print("\nIncome Level Distribution:")
print(income_counts)
# Out:
# Income Level Distribution:
# income
# 3    949
# 1    405
# 2    149
# 4     48
# 5     34
# 0     15
# Name: count, dtype: int64

# %%
# Plot gender distribution
plt.figure(figsize=(8, 5))
sns.countplot(data=data, x='sex')
plt.title('Gender Distribution among Voters')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# Plot education level distribution
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='education', order=data['education'].value_counts().index)
plt.title('Education Level Distribution among Voters')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Histogram of Age Distribution
plt.figure(figsize=(10, 6))
sns.histplot(data['age'], bins=20, kde=True)
plt.title('Age Distribution among Voters')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.axvline(age_summary['mean'], color='r', linestyle='--', label='Mean Age')
plt.axvline(age_summary['50%'], color='g', linestyle='--', label='Median Age')
plt.legend()
plt.show()

# %%
# Calculate the average age of voters
average_age = data['age'].mean()
print(f"The average age of voters is: {average_age:.2f} years")
# Out:
# The average age of voters is: 49.94 years

# %%
# Calculate the median age of voters
median_age = data['age'].median()
print(f"The median age of voters is: {median_age:.2f} years")
# Out:
# The median age of voters is: 49.00 years

# %% [markdown]
# ### age range that makes up the majority of voters

# %%
# Define age bins and labels
bins = [18, 25, 35, 45, 55, 65, 75, 85, 95]
labels = ['18-24', '25-34', '35-44', '45-54', '55-64', '65-74', '75-84', '85+']

# Create a new column for age groups
data['age_group'] = pd.cut(data['age'], bins=bins, labels=labels, right=False)

# Count occurrences of each age group
age_group_counts = data['age_group'].value_counts().sort_index()
print("\nAge Group Counts:")
print(age_group_counts)

# Find the most common age group
most_common_age_group = age_group_counts.idxmax()
most_common_count = age_group_counts.max()

print(f"\nThe most common age range among voters is: {most_common_age_group} with {most_common_count} voters.")
# Out:
# Age Group Counts:
# age_group
# 18-24    116
# 25-34    189
# 35-44    361
# 45-54    280
# 55-64    279
# 65-74    240
# 75-84    123
# 85+       12
# Name: count, dtype: int64
#
# The most common age range among voters is: 35-44 with 361 voters.
